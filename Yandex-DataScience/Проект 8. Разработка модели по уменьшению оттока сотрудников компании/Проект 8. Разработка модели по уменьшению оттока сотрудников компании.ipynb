# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Разработка-модели-по-уменьшению-оттока-сотрудников-компании" data-toc-modified-id="Разработка-модели-по-уменьшению-оттока-сотрудников-компании-1">Разработка модели по уменьшению оттока сотрудников компании</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1">Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2">Описание данных</a></span></li><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.3">Импорт библиотек</a></span></li></ul></li><li><span><a href="#Задача-1" data-toc-modified-id="Задача-1-2">Задача 1</a></span><ul class="toc-item"><li><span><a href="#1.-Загрузка-данных" data-toc-modified-id="1.-Загрузка-данных-2.1">1. Загрузка данных</a></span></li><li><span><a href="#1.2.-Предобработка-данных" data-toc-modified-id="1.2.-Предобработка-данных-2.2">1.2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#1.2.1.-Ошибки-в-данных" data-toc-modified-id="1.2.1.-Ошибки-в-данных-2.2.1">1.2.1. Ошибки в данных</a></span></li><li><span><a href="#1.2.2.-Поиск-аномальных-значений" data-toc-modified-id="1.2.2.-Поиск-аномальных-значений-2.2.2">1.2.2. Поиск аномальных значений</a></span></li></ul></li><li><span><a href="#1.3.-Исследовательский-анализ-данных" data-toc-modified-id="1.3.-Исследовательский-анализ-данных-2.3">1.3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#1.3.1-Рассмотрим-непрерывные-количественные-признаки" data-toc-modified-id="1.3.1-Рассмотрим-непрерывные-количественные-признаки-2.3.1">1.3.1 Рассмотрим непрерывные количественные признаки</a></span></li><li><span><a href="#1.3.2-Рассмотрим-категориальные-признаки" data-toc-modified-id="1.3.2-Рассмотрим-категориальные-признаки-2.3.2">1.3.2 Рассмотрим категориальные признаки</a></span></li><li><span><a href="#1.3.3.-Корреляционный-анализ-данных" data-toc-modified-id="1.3.3.-Корреляционный-анализ-данных-2.3.3">1.3.3. Корреляционный анализ данных</a></span></li><li><span><a href="#1.3.4.Выводы" data-toc-modified-id="1.3.4.Выводы-2.3.4">1.3.4.Выводы</a></span></li></ul></li><li><span><a href="#1.4.-Подготовка-данных" data-toc-modified-id="1.4.-Подготовка-данных-2.4">1.4. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#1.4.1.Создание-пайплайна" data-toc-modified-id="1.4.1.Создание-пайплайна-2.4.1">1.4.1.Создание пайплайна</a></span></li></ul></li><li><span><a href="#1.5.-Обучение-модели" data-toc-modified-id="1.5.-Обучение-модели-2.5">1.5. Обучение модели</a></span></li><li><span><a href="#1.6.-Выводы" data-toc-modified-id="1.6.-Выводы-2.6">1.6. Выводы</a></span></li></ul></li><li><span><a href="#Задача-2" data-toc-modified-id="Задача-2-3">Задача 2</a></span><ul class="toc-item"><li><span><a href="#2.1.-Загрузка-данных" data-toc-modified-id="2.1.-Загрузка-данных-3.1">2.1. Загрузка данных</a></span></li><li><span><a href="#2.2.-Предобработка-данных" data-toc-modified-id="2.2.-Предобработка-данных-3.2">2.2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#2.2.1.-Ошибки-в-данных" data-toc-modified-id="2.2.1.-Ошибки-в-данных-3.2.1">2.2.1. Ошибки в данных</a></span></li><li><span><a href="#2.2.2.-Поиск-аномальных-значений" data-toc-modified-id="2.2.2.-Поиск-аномальных-значений-3.2.2">2.2.2. Поиск аномальных значений</a></span></li></ul></li><li><span><a href="#2.3.-Исследовательский-анализ-данных" data-toc-modified-id="2.3.-Исследовательский-анализ-данных-3.3">2.3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#2.3.1." data-toc-modified-id="2.3.1.-3.3.1">2.3.1.</a></span></li><li><span><a href="#2.3.2.-Составьте-портрет-«уволившегося-сотрудника»" data-toc-modified-id="2.3.2.-Составьте-портрет-«уволившегося-сотрудника»-3.3.2">2.3.2. Составьте портрет «уволившегося сотрудника»</a></span></li><li><span><a href="#2.3.3." data-toc-modified-id="2.3.3.-3.3.3">2.3.3.</a></span></li></ul></li><li><span><a href="#2.4-Добавление-нового-входного-признака" data-toc-modified-id="2.4-Добавление-нового-входного-признака-3.4">2.4 Добавление нового входного признака</a></span></li><li><span><a href="#2.5.-Подготовка-данных" data-toc-modified-id="2.5.-Подготовка-данных-3.5">2.5. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#2.5.1.-Создание-пайплайна" data-toc-modified-id="2.5.1.-Создание-пайплайна-3.5.1">2.5.1. Создание пайплайна</a></span></li></ul></li><li><span><a href="#2.6.-Обучение-модели" data-toc-modified-id="2.6.-Обучение-модели-3.6">2.6. Обучение модели</a></span></li></ul></li><li><span><a href="#Выводы-по-проекту:" data-toc-modified-id="Выводы-по-проекту:-4">Выводы по проекту:</a></span></li></ul></div>

# %% [markdown]
# # Разработка модели по уменьшению оттока сотрудников компании

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
#
# В проекту будет несколько задач. Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# - id — уникальный идентификатор сотрудника;
# - dept — отдел, в котором работает сотрудник;
# - level — уровень занимаемой должности;
# - workload — уровень загруженности сотрудника;
# - employment_years — длительность работы в компании (в годах);
# - last_year_promo — показывает, было ли повышение за последний год;
# - last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# - salary — ежемесячная зарплата сотрудника;
# - job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.

# %% [markdown]
# Тренировочная выборка:
# - train_job_satisfaction_rate.csv
#
# Входные признаки тестовой выборки:
# - test_features.csv
#
# Целевой признак тестовой выборки:
# - test_target_job_satisfaction_rate.csv

# %% [markdown]
# ## Импорт библиотек

# %%
#pip install shap

# %%
#pip install phik

# %%
#pip install -U scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import shap
import math

from phik import phik_matrix
from phik.report import plot_correlation_matrix

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, LabelEncoder, RobustScaler
from sklearn.compose import ColumnTransformer

#модели
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier

#метрики
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import make_scorer

from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

RANDOM_STATE = 42

# %% [markdown]
# Функции для постройки графиков:

# %%
def plot_histograms_boxplots(df):
    """
    Строит гистограммы и ящики с усами для каждого количественного фактора в DataFrame.

    """
    # Выбор числовых столбцов
    numeric_cols = df.select_dtypes(include=['number']).columns

    # Установка размера фигуры
    num_plots = len(numeric_cols)
    plt.figure(figsize=(10, 5 * num_plots))

    # Построение гистограмм и ящиков с усами для каждого числового столбца
    for i, col in enumerate(numeric_cols):
        # Гистограмма
        plt.subplot(num_plots, 2, 2*i + 1)
        df[col].hist(bins=15)
        plt.title(f'Гистограма {col}')
        plt.xlabel(col)
        plt.ylabel('Частота')

        # Ящик с усами
        plt.subplot(num_plots, 2, 2*i + 2)
        df.boxplot(column=col)
        plt.title(f'Box Plot of {col}')

    plt.tight_layout()
    plt.show()

# %%
def plot_countplots(df):
    """
    Строит countplots для каждого категориального фактора в DataFrame.

    """
    # Выбор категориальных столбцов
    categorical_cols = df.select_dtypes(exclude=['number']).columns

    # Установка размера фигуры
    num_plots = len(categorical_cols)
    plt.figure(figsize=(10, 5 * num_plots))

    # Построение countplots для каждого категориального столбца
    for i, col in enumerate(categorical_cols):
        plt.subplot(num_plots, 1, i + 1)
        sns.countplot(y=col, data=df)
        plt.title(f'График {col}')
        plt.xlabel(col)
        plt.ylabel('Количество')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Задача 1

# %% [markdown]
# ## 1. Загрузка данных

# %% [markdown]
# Имеют следующие данные:
# 1. Тренировочная выборка: **train_job_satisfaction_rate.csv**
# 2. Входные признаки тестовой выборки:  **test_features.csv**
# 3. Целевой признак тестовой выборки:  **test_target_job_satisfaction_rate.csv**

# %%
train = pd.read_csv('C://Users/rdl_b/OneDrive/Рабочий стол/python/Yandex Practicum/Загрузка проектов/Проект 8 (сборный)/train_job_satisfaction_rate.csv')
X_test = pd.read_csv('C://Users/rdl_b/OneDrive/Рабочий стол/python/Yandex Practicum/Загрузка проектов/Проект 8 (сборный)/test_features.csv')
y_test = pd.read_csv('C://Users/rdl_b/OneDrive/Рабочий стол/python/Yandex Practicum/Загрузка проектов/Проект 8 (сборный)/test_target_job_satisfaction_rate.csv')

# %% [markdown]
# **Посмотрим первые строки датасетов и общую информацию**

# %%
train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
X_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %%
y_test.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
def info(df):
    df.info()
    print('\nКоличество дубликатов:',df.duplicated().sum(),'\n')
    print('Количество пропусков:\n',df.isna().sum())

# %%
info(train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
#
# Количество дубликатов: 0
#
# Количество пропусков:
#  id                       0
# dept                     6
# level                    4
# workload                 0
# ...

# %%
info(X_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#
# Количество дубликатов: 0
#
# Количество пропусков:
#  id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# ...

# %%
info(y_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
#
# Количество дубликатов: 0
#
# Количество пропусков:
#  id                       0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# **Выводы** :
# 1. Тренировочная выборка: 4000 строк, есть пропуски в столбце с отделом и занимаемой должностью, дублей нет, форматы данных соответсвуют данным.
# 2. Тестовая выборка: 2000 строк, есть пропуски в столбце с отделом и занимаемой должностью, дублей нет, форматы данных соответсвуют данным.
# 3. Тестовая выборка с целевым признаком: 2000 строк, пропусков нет, дублей нет, форматы данных соответсвуют данным.
# 4. Пропусками займемся на этапе подготовки данных в пайплайне

# %% [markdown]
# ## 1.2. Предобработка данных

# %% [markdown]
# ### 1.2.1. Ошибки в данных

# %% [markdown]
# Так как дубликатов в данных нет, а все форматы соответствуют данным, то займемся поиском ошибок в данных. Для этого изучим уникальные значения во всех колонках типа **object.**

# %%
def func(data):
    for col in data.select_dtypes(include=['object', 'category']).columns:
        print('Столбец:', col, data[col].unique(), '\n', '\n')

# %%
func(train)
# Out:
# Столбец: dept ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
#
#
# Столбец: level ['junior' 'middle' 'sinior' nan]
#
#
# Столбец: workload ['medium' 'high' 'low']
#
#
# Столбец: last_year_promo ['no' 'yes']
#
#
# Столбец: last_year_violations ['no' 'yes']

# %%
dept_with_nan = train.loc[train['dept'].isnull()]
dept_with_nan
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 1526  694746  NaN  junior   medium                 5              no
# 1630  814624  NaN  junior   medium                 3              no
# 1633  475114  NaN  junior     high                 4              no
# 2781  497243  NaN  junior   medium                 1              no
# 2975  168668  NaN  junior      low                 3              no
# 3866  641150  NaN  junior      low                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1526                   no                      4   21600
# 1630                   no                      4   24000
# 1633                   no                      4   31200
# 2781                   no                      3   26400
# 2975                   no                      4   18000
# 3866                  yes                      4   12000
#
#       job_satisfaction_rate
# 1526                   0.62
# ...

# %%
level_with_nan = train.loc[train['level'].isnull()]
level_with_nan
# Out:
#           id   dept level workload  employment_years last_year_promo  \
# 1209  631073  sales   NaN   medium                 1              no
# 1469  416327  sales   NaN      low                 1              no
# 1745  135043  sales   NaN   medium                 1              no
# 2522  998838  sales   NaN   medium                 1              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1209                   no                      4   27600
# 1469                   no                      5   18000
# 1745                   no                      3   26400
# 2522                   no                      5   27600
#
#       job_satisfaction_rate
# 1209                   0.66
# 1469                   0.73
# 1745                   0.30
# 2522                   0.71

# %% [markdown]
# Есть ошибка в столбце **level** - значение *sinior*, но это не на что не влияет для исследования

# %%
func(X_test)
# Out:
# Столбец: dept ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
#
#
# Столбец: level ['junior' 'middle' 'sinior' nan]
#
#
# Столбец: workload ['medium' 'low' 'high' ' ']
#
#
# Столбец: last_year_promo ['no' 'yes']
#
#
# Столбец: last_year_violations ['no' 'yes']

# %%
dept_with_miss = X_test.loc[X_test['dept'] == ' ']
dept_with_miss
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 1699  822186       middle   medium                 3              no
#
#      last_year_violations  supervisor_evaluation  salary
# 1699                   no                      4   38400

# %% [markdown]
# В столбцах dept и workload - пустые значения, заменим ин на nan

# %%
X_test.loc[X_test['dept'] == ' ', 'dept'] = np.nan
X_test.loc[X_test['workload'] == ' ', 'workload'] = np.nan

# %%
dept_with_miss = X_test.loc[X_test['workload'] == ' ']
dept_with_miss
# Out:
# Empty DataFrame
# Columns: [id, dept, level, workload, employment_years, last_year_promo, last_year_violations, supervisor_evaluation, salary]
# Index: []

# %%
func(X_test)
# Out:
# Столбец: dept ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan]
#
#
# Столбец: level ['junior' 'middle' 'sinior' nan]
#
#
# Столбец: workload ['medium' 'low' 'high' nan]
#
#
# Столбец: last_year_promo ['no' 'yes']
#
#
# Столбец: last_year_violations ['no' 'yes']

# %% [markdown]
# ### 1.2.2. Поиск аномальных значений

# %% [markdown]
# Найдем аномальные значения в количественных признаках. Для этого воспользуемся функцией, которая строит гистограмму и "ящик с усами" для всех признаков

# %%
plot_histograms_boxplots(train.drop(labels='id', axis = 1))

# %% [markdown]
# Отрицательных и аномальных значений в тренировочной выборке не выявлено. На диаграммах "ящик с усами" в колонках supervisor_evaluation и salary имеются выбросы, но мы их трогать не будем.
#
# В колонках employment_years и supervisor_evaluation всего 10 и 5 вариантов числовых значений соответственно, похоже что это дискретные признаки, но подробным анализом признаков мы займемся на следующем этапе. Итог по всем колонкам: данные выглядят достоверно.

# %%
plot_histograms_boxplots(X_test.drop(labels='id', axis = 1))

# %% [markdown]
# В тестовой выборке картина аналогичная тренировочной. Отрицательных и аномальных значений нет, данные выглядят достоверно.

# %% [markdown]
# **Выводы по преобработки данных:**
#
# 1. Есть ошибка в столбце level - значение sinior, но это не на что не влияет для исследования
# 2. Были обнаружены пропуски в данных и заменены значениями nan, в дальнейшем они будут заполнены в пайплайне
# 3. Отрицательных и аномальных значений в тренировочной выборке не выявлено. На диаграммах "ящик с усами" в колонках supervisor_evaluation и salary имеются выбросы.
# 4. В колонках employment_years и supervisor_evaluation всего 10 и 5 вариантов числовых значений соответственно, похоже что это дискретные признаки, но подробным анализом признаков мы займемся на следующем этапе. Итог по всем колонкам: данные выглядят достоверно.
# 5. В тестовой выборке картина аналогичная тренировочной. Отрицательных и аномальных значений нет, данные выглядят достоверно.

# %% [markdown]
# ## 1.3. Исследовательский анализ данных

# %% [markdown]
# Проведем статистический анализ всех признаков. Начнем с количественных признаков.

# %%
train.describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary  \
# count    4000.000000       4000.000000            4000.000000   4000.000000
# mean   544957.621000          3.718500               3.476500  33926.700000
# std    257883.104622          2.542513               1.008812  14900.703838
# min    100954.000000          1.000000               1.000000  12000.000000
# 25%    322836.750000          2.000000               3.000000  22800.000000
# 50%    534082.500000          3.000000               4.000000  30000.000000
# 75%    771446.000000          6.000000               4.000000  43200.000000
# max    999521.000000         10.000000               5.000000  98400.000000
#
#        job_satisfaction_rate
# count            4000.000000
# mean                0.533995
# std                 0.225327
# min                 0.030000
# 25%                 0.360000
# 50%                 0.560000
# 75%                 0.710000
# max                 1.000000

# %%
X_test.describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary
# count    2000.000000       2000.000000            2000.000000   2000.000000
# mean   552765.213500          3.666500               3.526500  34066.800000
# std    253851.326129          2.537222               0.996892  15398.436729
# min    100298.000000          1.000000               1.000000  12000.000000
# 25%    339052.000000          1.000000               3.000000  22800.000000
# 50%    550793.000000          3.000000               4.000000  30000.000000
# 75%    765763.750000          6.000000               4.000000  43200.000000
# max    999029.000000         10.000000               5.000000  96000.000000

# %%
y_test.describe()
# Out:
#                   id  job_satisfaction_rate
# count    2000.000000             2000.00000
# mean   552765.213500                0.54878
# std    253851.326129                0.22011
# min    100298.000000                0.03000
# 25%    339052.000000                0.38000
# 50%    550793.000000                0.58000
# 75%    765763.750000                0.72000
# max    999029.000000                1.00000

# %% [markdown]
# Данные в тренировочной и тестовой выборках распределены достаточно равномерно. Средние, медианные, максимальные и минимальные значения в них примерно одинаковые. А значит модели будет легче предсказывать удовлетворенность на тестовой выборке.

# %% [markdown]
# ### 1.3.1 Рассмотрим непрерывные количественные признаки

# %% [markdown]
# Ещё раз построим гистограммы:

# %%
train['salary'].hist(label='train').set_title('Ежемесячная зарплата сотрудника')
X_test['salary'].hist(label='X_test')
plt.legend()

# %%
train['job_satisfaction_rate'].hist(label='train').set_title('Уровень удовлетворенности сотрудника компанией')
y_test['job_satisfaction_rate'].hist(label='y_test')
plt.legend()

# %% [markdown]
# Непрерывные количественные признаки распределены не совсем равномерно. В ежемесячной зарпл/ате сотрудников имеется сдвиг влево, а в уровне удовлетворенности сотрудников - сдвиг вправо. В тренировочной и тестовой выборках картина примерно одинаковая.
# Масштаб у данных сильно отличается, поэтому для подготовки данных придется использовать масштабирование.

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x ='employment_years', data = train).set(title='Длительность работы в компании', 
                                                    xlabel='Годы работы', ylabel='Кол-во сотрудников')
plt.subplot(1, 2, 2)
sns.countplot(x ='employment_years', data = X_test).set(title='Длительность работы в компании', 
                                                    xlabel='Годы работы', ylabel='Кол-во сотрудников')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.countplot(x ='supervisor_evaluation', data = train).set(title='Оценка качества работы сотрудника', 
                                                    xlabel='Оценка', ylabel='Кол-во сотрудников')
plt.subplot(1, 2, 2)
sns.countplot(x ='supervisor_evaluation', data = X_test).set(title='Оценка качества работы сотрудника', 
                                                    xlabel='Оценка', ylabel='Кол-во сотрудников')
plt.show()

# %% [markdown]
# Преобладают сотрудники, которые работают в компании один год, видно, что чем больше лет в компании, тем меньше сотрудников. В оценках сотрудников преобладают оценки 3 и 4. Соотношения значений в тренировочной и тестовой выборках примерно одинаковые

# %% [markdown]
# ### 1.3.2 Рассмотрим категориальные признаки

# %%
train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
# Вычисляем количество сотрудников по отделам
train_counts = train['dept'].value_counts()
test_counts = X_test['dept'].value_counts()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(train_counts, labels=train_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по отделам (train)')

plt.subplot(1, 2, 2)
plt.pie(test_counts, labels=test_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по отделам (X_test)')

plt.tight_layout()
plt.show()

# %%
# Вычисляем количество сотрудников по уровням должности
train_counts = train['level'].value_counts()
test_counts = X_test['level'].value_counts()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(train_counts, labels=train_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по уровням должности (train)')

plt.subplot(1, 2, 2)
plt.pie(test_counts, labels=test_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по уровням должности (X_test)')

plt.tight_layout()
plt.show()

# %%
# Вычисляем количество сотрудников по загруженности
train_counts = train['workload'].value_counts()
test_counts = X_test['workload'].value_counts()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(train_counts, labels=train_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по загруженности (train)')

plt.subplot(1, 2, 2)
plt.pie(test_counts, labels=test_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по загруженности (X_test)')

plt.tight_layout()
plt.show()

# %%
# Вычисляем количество сотрудников по загруженности
train_counts = train['last_year_promo'].value_counts()
test_counts = X_test['last_year_promo'].value_counts()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(train_counts, labels=train_counts.index, autopct='%1.0f%%', startangle=0)
plt.title('Соотношение кол-ва сотрудников по повышениям (train)')

plt.subplot(1, 2, 2)
plt.pie(test_counts, labels=test_counts.index, autopct='%1.0f%%', startangle=0)
plt.title('Соотношение кол-ва сотрудников по повышениям (X_test)')

plt.tight_layout()
plt.show()

# %%
# Вычисляем количество сотрудников по загруженности
train_counts = train['last_year_violations'].value_counts()
test_counts = X_test['last_year_violations'].value_counts()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(train_counts, labels=train_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по нарушениям (train)')

plt.subplot(1, 2, 2)
plt.pie(test_counts, labels=test_counts.index, autopct='%1.0f%%', startangle=140)
plt.title('Соотношение кол-ва сотрудников по нарушениям (X_test)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Выводы по диаграммам:
# 1. Среди сотрудников компании по отделам преобладают продажники
# 2. Преобладающие уровни должностей - junior и middle
# 3. Больше всего сотрудников средней загруженности
# 4. Повышение было только у 3% сотрудников
# 4. 14% сотрудников нарушали трудовой договор
#
# Распределение данных в тестовой и тренировочной выборках практически идентичное.
#
# 1. Для признаков с нарушениями и повышениями можно использовать OneHotEncoder
# 2. Для остальных OrdinalEncoder
# 3. Уровень должности и уровень загруженности это ранговые признаки.

# %% [markdown]
# ### 1.3.3. Корреляционный анализ данных

# %%
train_id = train.set_index('id')

# %%
interval_cols = ['salary', 'job_satisfaction_rate']

# Вычисление матрицы корреляции phi для первой части (покупательская активность = 'снизилась')
train_id = phik_matrix(train_id, interval_cols=interval_cols)

# Визуализация тепловой карты корреляций для первой части
plot_correlation_matrix(
    train_id.values,
    x_labels=train_id.columns,
    y_labels=train_id.index,
    title=r"correlation $\phi_K$",
    fontsize_factor=1.5,
    figsize=(15, 12)
)

# %% [markdown]
# Утечки целевого признака не обнаружено.

# %% [markdown]
# ### 1.3.4.Выводы

# %% [markdown]
# 1. Масштаб у данных сильно отличается, поэтому для подготовки данных придется использовать масштабирование
# 2. Соотношения значений в тренировочной и тестовой выборках примерно одинаковые
# 3. Распределение данных в тестовой и тренировочной выборках практически идентичное.
# 4. Для признаков с нарушениями и повышениями можно использовать OneHotEncoder
# 5. Для остальных OrdinalEncoder
# 6. Уровень должности и уровень загруженности это ранговые признаки.
# 7. Утечки целевого признака не обнаружено.

# %% [markdown]
# ## 1.4. Подготовка данных

# %% [markdown]
# Перечислим что будем делать с данными:
#
# - Нарушения трудового договора (last_year_violations), Повышение за последний год (last_year_promo), Отдел (dept) — кодируем с помощью OneHotEncoder.
# - Уровень должности (level) и Уровень загруженности (workload) — нужно кодировать с помощью OrdinalEncoder, это ранговые признаки.
# - В признаках, встречаются пропуски (Используем SimpleImputer)
# - Целевой признак — Удовлетворённость сотрудника работой в компании (job_satisfaction_rate).
# -  Количественные признаки: Количество лет в компании (employment_years), Оценка работодателя (supervisor_evaluation) и Зарплата (salary) - масштабируем.

# %% [markdown]
# Сначала удалим "id"

# %%
train_without_id = train.drop(['id'], axis=1)

# %% [markdown]
# Разделим тренировочную выборку на две: с целевым и без него.

# %%
X_train = train_without_id.drop(['job_satisfaction_rate'], axis=1)
y_train = train_without_id['job_satisfaction_rate']
X_train.shape
# Out:
# (4000, 8)

# %%
func(X_train)
# Out:
# Столбец: dept ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
#
#
# Столбец: level ['junior' 'middle' 'sinior' nan]
#
#
# Столбец: workload ['medium' 'high' 'low']
#
#
# Столбец: last_year_promo ['no' 'yes']
#
#
# Столбец: last_year_violations ['no' 'yes']

# %%
test = X_test.merge(y_test, on='id')

# %%
X_test_ = test.drop(['job_satisfaction_rate','id'], axis=1)
y_test_ = test['job_satisfaction_rate']
X_test_.shape
# Out:
# (2000, 8)

# %%
num_columns = ['salary', 'employment_years', 'supervisor_evaluation'] 
ohe_columns = ['last_year_violations', 'last_year_promo','dept']
ord_columns = ['level','workload']

# %% [markdown]
# ### 1.4.1.Создание пайплайна

# %%
ohe_pipe = Pipeline(
        [
            (
                'simpleImputer_ohe', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            ),
            (
                'ohe', 
                OneHotEncoder(drop='first', handle_unknown='ignore')
            )
        ]
    )

# %%
ord_pipe = Pipeline(
        [
            (
                'simpleImputer_before_ord', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            ),
            (
                'ord',  
                OrdinalEncoder(
                    categories=[ 
                        ['junior', 'middle', 'sinior'],
                        ['low', 'medium', 'high'],
                    ], 
                    handle_unknown='use_encoded_value', unknown_value=np.nan
                )
            ),
            (
                'simpleImputer_after_ord', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            )
        ]
    )

# %%
data_preprocessor = ColumnTransformer([
            ('ohe', ohe_pipe, ohe_columns),
            ('ord', ord_pipe, ord_columns),
            ('num', StandardScaler(), num_columns)], 
        remainder='passthrough')

# %%
pipe_final = Pipeline([
        ('preprocessor', data_preprocessor),
        ('models', LinearRegression())])

# %% [markdown]
# ## 1.5. Обучение модели

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(5, 14),
        'models__max_features': range(5, 14),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    {
        'models': [LinearRegression()]
    }
    
]

# %% [markdown]
# Создадим метрику SMAPE, используя функцию:

# %%
def smape(y_true, y_pred):
    return 100 * np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))

# %%
smape_scorer = make_scorer(smape, greater_is_better=False)

# %%
grid = GridSearchCV(
    pipe_final, 
    param_grid=param_grid, 
    cv=5,
    scoring=smape_scorer,
    n_jobs=-1
)

grid.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid.best_score_*-1)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['last_year_violations',
#                                                    'last_year_promo', 'dept']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %% [markdown]
# Лучшая модель: DecisionTreeRegressor(max_depth=13, max_features=8) - дерево решений, с максимальной глубиной - 13, максимальным числом признаков - 8
#
# Проверим значения метрики SMAPE на тестовой выборке

# %%
y_pred_test = grid.best_estimator_.predict(X_test_)
smape_test = smape(y_test_, y_pred_test)
print ("Метрика SMAPE равна:", smape_test)
# Out:
# Метрика SMAPE равна: 14.650693564366952

# %% [markdown]
# Метрика получилась равной 14.65, лучше чем на тренировочной выборке.

# %%
results = pd.DataFrame(grid.cv_results_)
results.mean_test_score = results.mean_test_score * -1
results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.044281      0.007505         0.028724        0.016919
# 1         0.045678      0.006688         0.023737        0.014691
# 2         0.051262      0.018813         0.016157        0.008472
# 3         0.036104      0.009800         0.019747        0.008354
# 4         0.040890      0.013646         0.020745        0.011875
# ..             ...           ...              ...             ...
# 320       0.045979      0.011255         0.025337        0.013796
# 321       0.049277      0.014018         0.013169        0.002635
# 322       0.038896      0.005007         0.013764        0.002475
# 323       0.038496      0.009023         0.012965        0.003838
# 324       0.052068      0.022983         0.017358        0.004160
#
#                                param_models param_models__max_depth  \
# 0    DecisionTreeRegressor(random_state=42)                       5
# ...

# %% [markdown]
# По таблице видно, что результаты разных моделей отличаются друг от друга, при увеличении глубины дерева решений увеличивается точность предсказаний. Результаты линейной регрессии хуже, чем у дерева решений.

# %% [markdown]
# ## 1.6. Выводы

# %% [markdown]
# 1. Была построена модель, которая может предсказать уровень удовлетворенности сотрудника на основе данных заказчика.\
# 2. После обучения нескольких моделей мы выбрали лучшую, оценивая их производительность с помощью метрики SMAPE.
# 3. Лучшей оказалась модель дерева решений, которая была настроена с максимальной глубиной 13 и максимальным числом признаков, используемых для разделения данных в дереве, равным 8.
# 4. Вероятно, модель дерева решений показала себя лучше, чем линейная регрессия, благодаря своей способности более гибко настраиваться за счет изменения гиперпараметров.

# %%
preprocessor = grid.best_estimator_['preprocessor']
ohe_feature_names = preprocessor.named_transformers_['ohe'].get_feature_names_out(input_features=ohe_columns)
ord_feature_names = ord_columns
num_feature_names = num_columns
all_feature_names = np.concatenate([ohe_feature_names, ord_feature_names, num_feature_names])
best_model = grid.best_estimator_.named_steps['models']

X_train_encoded = preprocessor.fit_transform(X_train)

explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X_train_encoded)

shap.summary_plot(shap_values, X_train_encoded, feature_names=all_feature_names, plot_type='bar')

# %% [markdown]
# # Задача 2

# %% [markdown]
# ## 2.1. Загрузка данных

# %%
train_quit = pd.read_csv('C://Users/rdl_b/OneDrive/Рабочий стол/python/Yandex Practicum/Загрузка проектов/Проект 8 (сборный)/train_quit.csv')
X_test_quit = pd.read_csv('C://Users/rdl_b/OneDrive/Рабочий стол/python/Yandex Practicum/Загрузка проектов/Проект 8 (сборный)/test_features.csv')
y_test_quit = pd.read_csv('C://Users/rdl_b/OneDrive/Рабочий стол/python/Yandex Practicum/Загрузка проектов/Проект 8 (сборный)/test_target_quit.csv')

# %% [markdown]
# **Посмотрим первые строки датасетов и общую информацию**

# %%
train_quit.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
y_test_quit
# Out:
#           id quit
# 0     999029  yes
# 1     372846   no
# 2     726767   no
# 3     490105   no
# 4     416898  yes
# ...      ...  ...
# 1995  836109  yes
# 1996  180999  yes
# 1997  746018   no
# 1998  247658   no
# 1999  460332  yes
#
# [2000 rows x 2 columns]

# %%
info(train_quit)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
#
# Количество дубликатов: 0
#
# Количество пропусков:
#  id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# ...

# %%
info(X_test_quit)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#
# Количество дубликатов: 0
#
# Количество пропусков:
#  id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# ...

# %%
info(y_test_quit)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
#
# Количество дубликатов: 0
#
# Количество пропусков:
#  id      0
# quit    0
# dtype: int64

# %% [markdown]
# ## 2.2. Предобработка данных

# %% [markdown]
# ### 2.2.1. Ошибки в данных

# %% [markdown]
# Так как дубликатов в данных нет, а все форматы соответствуют данным, то займемся поиском ошибок в данных. Для этого изучим уникальные значения во всех колонках типа **object.**

# %%
func(train_quit)
# Out:
# Столбец: dept ['sales' 'purchasing' 'marketing' 'technology' 'hr']
#
#
# Столбец: level ['middle' 'junior' 'sinior']
#
#
# Столбец: workload ['high' 'medium' 'low']
#
#
# Столбец: last_year_promo ['no' 'yes']
#
#
# Столбец: last_year_violations ['no' 'yes']
#
#
# Столбец: quit ['no' 'yes']

# %%
func(X_test_quit)
# Out:
# Столбец: dept ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
#
#
# Столбец: level ['junior' 'middle' 'sinior' nan]
#
#
# Столбец: workload ['medium' 'low' 'high' ' ']
#
#
# Столбец: last_year_promo ['no' 'yes']
#
#
# Столбец: last_year_violations ['no' 'yes']

# %%
func(y_test_quit)
# Out:
# Столбец: quit ['yes' 'no']

# %% [markdown]
# X_test_quit - есть ошибки, заменим их на nan

# %%
X_test_quit.loc[X_test_quit['dept'] == ' ', 'dept'] = np.nan
X_test_quit.loc[X_test_quit['workload'] == ' ', 'workload'] = np.nan

# %% [markdown]
# ### 2.2.2. Поиск аномальных значений

# %%
plot_histograms_boxplots(train_quit.drop(labels='id', axis = 1))

# %%
plot_histograms_boxplots(X_test_quit.drop(labels='id', axis = 1))

# %% [markdown]
# ## 2.3. Исследовательский анализ данных

# %% [markdown]
# Так как практически все данные мы уже исследовали раньше, посмотрим только распределение данных в новом целевом признаке.

# %% [markdown]
# ### 2.3.1.

# %%
train_quit
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 0     723290       sales  middle     high                 2              no
# 1     814010       sales  junior   medium                 2              no
# 2     155091  purchasing  middle   medium                 5              no
# 3     257132       sales  junior   medium                 2              no
# 4     910140   marketing  junior   medium                 2              no
# ...      ...         ...     ...      ...               ...             ...
# 3995  588809       sales  junior   medium                 4              no
# 3996  672059       sales  middle     high                 9              no
# 3997  536432  purchasing  junior      low                 2              no
# 3998  692133  purchasing  middle   medium                 2              no
# 3999  853842       sales  junior   medium                 2              no
#
# ...

# %%
y_test_quit
# Out:
#           id quit
# 0     999029  yes
# 1     372846   no
# 2     726767   no
# 3     490105   no
# 4     416898  yes
# ...      ...  ...
# 1995  836109  yes
# 1996  180999  yes
# 1997  746018   no
# 1998  247658   no
# 1999  460332  yes
#
# [2000 rows x 2 columns]

# %%
train_quit['quit'].hist(label='train').set_title('Соотношение кол-ва сотрудников по увольнениям')
y_test_quit['quit'].hist(label='y_test')
plt.legend()

# %%
train_counts = train_quit['quit'].value_counts()
test_counts = y_test_quit['quit'].value_counts()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(train_counts, labels=train_counts.index, autopct='%1.0f%%', startangle=0)
plt.title('Соотношение кол-ва сотрудников по увольнениям (train_quit)')

plt.subplot(1, 2, 2)
plt.pie(test_counts, labels=test_counts.index, autopct='%1.0f%%', startangle=0)
plt.title('Соотношение кол-ва сотрудников по увольнениям (y_test_quit)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Уволенных сотрудников 28% от общего количества. В тренировочной и тестовой выборках соотношение уволенных и не уводенных сотрудников примерно одинаковое

# %% [markdown]
# ### 2.3.2. Составьте портрет «уволившегося сотрудника»

# %%
train_quit
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 0     723290       sales  middle     high                 2              no
# 1     814010       sales  junior   medium                 2              no
# 2     155091  purchasing  middle   medium                 5              no
# 3     257132       sales  junior   medium                 2              no
# 4     910140   marketing  junior   medium                 2              no
# ...      ...         ...     ...      ...               ...             ...
# 3995  588809       sales  junior   medium                 4              no
# 3996  672059       sales  middle     high                 9              no
# 3997  536432  purchasing  junior      low                 2              no
# 3998  692133  purchasing  middle   medium                 2              no
# 3999  853842       sales  junior   medium                 2              no
#
# ...

# %%
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
sns.countplot(x ='dept', data = train_quit, hue = 'quit').set(title='Соотношение уволившихся и работающих сотрудников', 
                                                    xlabel='Отдел', ylabel='Кол-во сотрудников')

plt.subplot(1, 2, 2)
sns.countplot(x ='last_year_violations', data = train_quit, hue = 'quit').set(title='Соотношение уволившихся и работающих сотрудников', 
                                                    xlabel='Нарушения трудового договора', ylabel='Кол-во сотрудников')


plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
sns.countplot(x ='level', data = train_quit, hue = 'quit').set(title='Соотношение уволившихся и работающих сотрудников', 
                                                    xlabel='Уровень должности', ylabel='Кол-во сотрудников')
plt.subplot(1, 2, 2)
sns.countplot(x ='workload', data = train_quit, hue = 'quit').set(title='Соотношение уволившихся и работающих сотрудников', 
                                                    xlabel='Загруженность работой', ylabel='Кол-во сотрудников')
plt.show()



plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
sns.countplot(x ='supervisor_evaluation', data = train_quit, hue = 'quit').set(title='Соотношение уволившихся и работающих сотрудников', 
                                                    xlabel='Оценка работодателя', ylabel='Кол-во сотрудников')
plt.subplot(1, 2, 2)
sns.countplot(x ='employment_years', data = train_quit, hue = 'quit').set(title='Соотношение уволившихся и работающих сотрудников', 
                                                    xlabel='Кол-во лет работы', ylabel='Кол-во сотрудников')
plt.show()

# %%
salary_counts = train_quit.groupby(['salary', 'quit']).size().unstack(fill_value=0).sort_index()

plt.figure(figsize=(10, 6))
plt.plot(salary_counts.index, salary_counts['no'], label='Не воленные')
plt.plot(salary_counts.index, salary_counts['yes'], label='Уволенные')
plt.title('Соотношение уволившихся и работающих сотрудников в зависисости от зарплаты')
plt.xlabel('Зарплата')
plt.ylabel('Количество сотрудников')
plt.legend()
plt.grid(True)
plt.show()

# %%
train_quit.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
def calculate_quit_percentage(df, column_name):
    quit_counts = df.groupby(column_name)['quit'].value_counts(normalize=True).unstack().fillna(0)
    quit_counts['Доля уволенных'] = quit_counts['yes']
    quit_counts.drop(columns=['no', 'yes'], inplace=True)
    return quit_counts

# %%
quit_counts_dept = calculate_quit_percentage(train_quit, 'dept')
quit_counts_violations = calculate_quit_percentage(train_quit, 'last_year_violations')
quit_counts_level = calculate_quit_percentage(train_quit, 'level')
quit_counts_workload = calculate_quit_percentage(train_quit, 'workload')
quit_counts_supervisor_evaluation = calculate_quit_percentage(train_quit, 'supervisor_evaluation')
quit_counts_employment_years = calculate_quit_percentage(train_quit, 'employment_years')

# %%
def plot_quit_percentage(df1, df2, column1_name, column2_name, title1, title2):
    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    df1['Доля уволенных'].plot(kind='bar',color='skyblue')
    plt.title(title1)
    plt.xlabel(column1_name)
    plt.ylabel('Доля уволившихся сотрудников')
    plt.xticks(rotation=0) 
    plt.tight_layout()

    plt.subplot(1, 2, 2)
    df2['Доля уволенных'].plot(kind='bar', color='salmon')
    plt.title(title2)
    plt.xlabel(column2_name)
    plt.ylabel('Доля уволившихся сотрудников')
    plt.xticks(rotation=0) 
    plt.tight_layout()
    plt.show()

# %%
plot_quit_percentage(quit_counts_dept, quit_counts_violations, 'Отдел', 'Нарушение', 
                     'Доля уволившихся сотрудников по отделам', 
                     'Доля уволившихся сотрудников по нарушениям ТД')

plot_quit_percentage(quit_counts_level, quit_counts_workload, 'Уровень должности', 'Загруженность', 
                     'Доля уволившихся сотрудников по уровню должности', 
                     'Доля уволившихся сотрудников по Загруженности')

plot_quit_percentage(quit_counts_supervisor_evaluation, quit_counts_employment_years, 'Оценка', 'Стаж', 
                     'Доля уволившихся сотрудников по оценка от работодателя', 
                     'Доля уволившихся сотрудников по стажу работы')

# %% [markdown]
# Выводы по графикам:
# 1. Больше всего увольняются сотрудники с уровнем должности junior, с уровнем загруженности работой low, с низкими оценками от руководителя (1-3) и в течении первого года
# 2. Отдел не влиеят на увольнение сотрудника.
# 3. Чем ниже зарплата тем, выше вероятность что сотрудник уволится.
#
# Таким образом, типичный уволенный сотрудник - это недавно работающий не загруженный работой junior, которого не очень ценит руководитель, с низкой зарплатой.

# %% [markdown]
# ### 2.3.3.

# %% [markdown]
# Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки.

# %%
data1=y_test.merge(y_test_quit, on='id')

# %%
data1=data1.set_index('id')

# %%
interval_cols = ['job_satisfaction_rate']
phik_overview = phik_matrix(data1,interval_cols=interval_cols)

# %%
data1
# Out:
#         job_satisfaction_rate quit
# id
# 130604                   0.74   no
# 825977                   0.75   no
# 418490                   0.60  yes
# 555320                   0.72   no
# 826430                   0.08  yes
# ...                       ...  ...
# 405257                   0.28   no
# 370925                   0.21  yes
# 857722                   0.39   no
# 303402                   0.26  yes
# 648995                   0.62   no
#
# [2000 rows x 2 columns]

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    title=r"correlation $\phi_K$",
    fontsize_factor=1.5,
    figsize=(10, 6)
)

# %%
plt.figure(figsize=(15, 10))
sns.histplot(data=data1, x='job_satisfaction_rate', hue='quit', bins=20)
plt.title('Распределение "Удовлетворенностю работой" для ушедших и оставшихся работников')
plt.xlabel('Удовлетворенность работой')
plt.ylabel('Частота')
plt.legend(title='Уволены', labels=['no', 'yes'])
plt.show()

# %% [markdown]
# Удовлетворенность работой, достоточно сильно влияет на увольнение(целевой признак), думаю стоит использольвать этот параметр для построения модели

# %% [markdown]
# Выдвенем нулевую гипотезу: Средние значения job_satisfaction_rate для ушедших и оставшихся работников равны
# Используем t-тест Стьюдента

# %%
from scipy.stats import ttest_ind


quit_group = data1[data1['quit'] == 'yes']['job_satisfaction_rate']
stay_group = data1[data1['quit'] == 'no']['job_satisfaction_rate']


statistic, p_value = ttest_ind(quit_group, stay_group)

print(f"Значение t-статистики: {statistic}")
print(f"P-значение: {p_value}")

alpha = 0.05
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: существуют статистически значимые различия между группами.")
else:
    print("Не удалось отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.")
# Out:
# Значение t-статистики: -23.074784903634534
# P-значение: 1.231122066517193e-104
# Отвергаем нулевую гипотезу: существуют статистически значимые различия между группами.

# %% [markdown]
# Вывод: На основе этого анализа мы можем сделать вывод, что есть статистически значимые различия в уровне удовлетворенности работой между ушедшими и оставшимися работниками.
# Значение t-статистики равно -23.074784903634537. Отрицательное значение указывает на то, что среднее значение job_satisfaction_rate для группы уволенных сотрудников меньше, чем для группы оставшихся сотрудников

# %% [markdown]
# ## 2.4 Добавление нового входного признака

# %%
train_quit['job_satisfaction_rate_pred'] = grid.best_estimator_.predict(train_quit.drop(['quit'], axis=1))

# %%
train_quit.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    job_satisfaction_rate_pred
# 0                    0.650588
# 1                    0.826111
# 2                    0.340000
# 3                    0.380000
# ...

# %%
X_test_quit['job_satisfaction_rate_pred'] = grid.best_estimator_.predict(X_test)

# %%
X_test_quit.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  \
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
#
#    job_satisfaction_rate_pred
# 0                    0.855833
# 1                    0.676667
# 2                    0.657143
# 3                    0.655000
# 4                    0.826780

# %% [markdown]
# ## 2.5. Подготовка данных

# %% [markdown]
# Перечислем что у нас есть:
# train_quit - тренировочные данные
# X_test_quit - тестовые данный
# y_test_quit - целевой призак
#
# Ранее:
# - Нарушения трудового договора (**last_year_violations**), Повышение за последний год (**last_year_promo**), Отдел (**dept**) — кодируем с помощью **OneHotEncode**r.
# - Уровень должности (**level**) и Уровень загруженности (**workload**) — нужно кодировать с помощью **OrdinalEncoder**, это ранговые признаки.
# - В признаках, встречаются пропуски (Используем **SimpleImputer**)
# -  Количественные признаки: Количество лет в компании (**employment_years**), Оценка работодателя (**supervisor_evaluation**) и Зарплата (**salary**) - **масштабируем**.
#
# И дополнительно:
# - Целевой признак - увольнение сотрудника (**quit**) - закодирумем с помощью метода **LabelEncoder**.
# - Удовлетворённость сотрудника работой в компании (**job_satisfaction_rate**) - новый признак, количественный, поэтому **масштабируем**

# %%
train_quit_temp = train_quit.drop(['id'], axis = 1)

# %%
X_train_quit_model = train_quit_temp.drop(['quit'], axis=1)
y_train_quit_model = train_quit_temp['quit']
X_train_quit_model.shape
# Out:
# (4000, 9)

# %%
X_test_merge = X_test_quit.merge(y_test_quit, on='id')

# %%
X_test_model = X_test_merge.drop(['id','quit'], axis = 1)

# %%
y_test_model = X_test_merge['quit']

# %%
X_test_model.shape
# Out:
# (2000, 9)

# %%
label_encoder = LabelEncoder()
y_train_quit_model = label_encoder.fit_transform(y_train_quit_model)
y_test_model = label_encoder.transform(y_test_model)

# %% [markdown]
# ### 2.5.1. Создание пайплайна

# %%
num_columns = ['salary', 'employment_years', 'supervisor_evaluation', 'job_satisfaction_rate_pred'] 
ohe_columns = ['last_year_violations', 'last_year_promo','dept']
ord_columns = ['level','workload']

# %%
ohe_pipe = Pipeline(
        [
            (
                'simpleImputer_ohe', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            ),
            (
                'ohe', 
                OneHotEncoder(drop='first', handle_unknown='error')
            )
        ]
    )

# %%
ord_pipe = Pipeline(
        [
            (
                'simpleImputer_before_ord', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            ),
            (
                'ord',  
                OrdinalEncoder(
                    categories=[ 
                        ['junior', 'middle', 'sinior'],
                        ['low', 'medium', 'high'],
                    ], 
                    handle_unknown='use_encoded_value', unknown_value=np.nan
                )
            ),
            (
                'simpleImputer_after_ord', 
                SimpleImputer(missing_values=np.nan, strategy='most_frequent')
            )
        ]
    )

# %%
data_preprocessor = ColumnTransformer([
            ('ohe', ohe_pipe, ohe_columns),
            ('ord', ord_pipe, ord_columns),
            ('num', StandardScaler(), num_columns)], 
        remainder='passthrough')

# %%
pipe_final = Pipeline([
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))])

# %% [markdown]
# **Вывод**
# Проведена подготовка данных (кодирование (в том числе целевого признака), масштабирование, обработка пропусков) с использованием пайплайна.

# %% [markdown]
# ## 2.6. Обучение модели

# %% [markdown]
# Целевой признак - Увольнение.
# Т.к. варианта ответов 2, то это задача бинарной классификации.
# Для бинарной классификации нам подойдут модели логистической регрессии, метод опорных векторов, KNN и дерево решений (для всех используем перебор разных гиперпараметров).
#
# Зададим параметры этих четырех моделей

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', penalty='l1')],
        'models__C': [0.1, 1.0, 10.0, 100.0],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    # словарь для модели SVC()
    {
        'models': [SVC(probability=True, random_state=RANDOM_STATE)],
        'models__kernel': ['linear',  'rbf', 'poly', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %% [markdown]
# На этот раз используем RandomizedSearchCV, т.к. параметров очень много.
# Для оценки качества моделей будем использовать метрику ROC_AUC, как самую универсальную и сбалансированную метрику, которая не зависит от порога классификации.

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train_quit_model, y_train_quit_model)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first'))]),
#                                                                                ['last_year_violations',
#                                                                                 'last_year_promo',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first'))]),
#                                                   ['last_year_violations',
#                                                    'last_year_promo', 'dept']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent...
# ...

# %%
y_test_pred = randomized_search.predict_proba(X_test_model)

print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test_model, y_test_pred[:, 1])}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9277315583081451

# %%
X_train_transformed = pipe_final.named_steps['preprocessor'].fit_transform(X_train_quit_model)
X_test_transformed = pipe_final.named_steps['preprocessor'].transform(X_test_model)

# %%
feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()


X_train_smpl = shap.sample(X_train_transformed, 100, random_state=RANDOM_STATE)
X_test_smpl = shap.sample(X_test_transformed, 100, random_state=RANDOM_STATE)

explainer = shap.PermutationExplainer(randomized_search.best_estimator_.named_steps['models'].predict_proba, X_test_smpl)

explainer.feature_names = feature_names
shap_values_ = explainer(X_test_smpl)
shap.plots.bar(shap_values_[:,:,1], max_display=16)
# Out:
# PermutationExplainer explainer: 101it [05:04,  3.14s/it]

# %%
#explainer = shap.PermutationExplainer(randomized_search.best_estimator_.named_steps['models'].predict_proba, X_test_transformed)
#feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
#explainer.feature_names = feature_names
#shap_values_ = explainer(X_test_transformed)
#shap.plots.bar(shap_values_[:,:,1], max_display=16)

# %%
shap.plots.bar(shap_values_[:,:,1], max_display=16)

# %% [markdown]
# https://ibb.co/y85W804 - ссылка на график shap (чтобы долго не грузить)

# %%
shap.plots.beeswarm(shap_values_[:,:,1], max_display=16)

# %% [markdown]
# **Выводы**
#
# Метрика ROC-AUC на тестовой выборке: 0.9277315583081451. Лучше всего справилась модель SVC - метод опорных векторов.
# Больше всего на модель влияют следующие параметры: Стаж работы, уровень удовлетворённости и уровень занимаемой должности, а также зарплата

# %% [markdown]
# # Выводы по проекту:

# %% [markdown]
# В работе были выполнены 2 задачи: построили модель для определения уровня удовлетворенности, и модель для определения вероятности увольнения сотрудника

# %% [markdown]
# Для решения 1 задачи:
#    1. Тренировочная выборка: 4000 строк, есть пропуски в столбце с отделом и занимаемой должностью, дублей нет, форматы данных соответсвуют данным. Тестовая выборка: 2000 строк, есть пропуски в столбце с отделом и занимаемой должностью, дублей нет, форматы данных соответсвуют данным. Тестовая выборка с целевым признаком: 2000 строк, пропусков нет, дублей нет, форматы данных соответсвуют данным.
#    2. Провели предобработку данных. На этом этапе мы проверили данные на ошибки в категориальных признаках. Нашли пустые значения в двух колонках тестовой выборки и заменили их на NaN. Проверили количественных данные на достоверность и не нашли отрицательных и аномальных значений.
#    3. Провели исследовательский анализ данных, посмотрели распределение данных во всех таблицах, по итогам анализа можно сказать, что данные выглядят достоверно, особых выбросов нет, при проведении корреляционного анализа утечки целевого признака не обнаружено.
#    4. Провели подготовку данных (кодирование, масштабирование, обработка пропусков) с использованием пайплайна.
#    5. Так как целевой признак у нас непрерывный количественный, то для для обучения мы взяли две модели регрессии: модель линейной регрессии и дерево решений (для дерева решений использовали перебор разных гиперпараметров). Провели обучение моделей, выбрали лучшую на основе метрики SMAPE.
#    6. Лучшей оказалась модель дерева решений, которая была настроена с максимальной глубиной 13 и максимальным числом признаков, используемых для разделения данных в дереве, равным 8.
#
#    Для решения 2 задачи:
#    1. Провели загрузку новых данных. В новых датасетах пропусков и дублей нет. В тренировочной выборке всё так же 4000 строк, в тестовой 2000.
#    2. Провели предобработку данных. В новых колонках quit в тренировочной и тестовой выборках ошибок не обнаружено. Данные распределены так же, как в первой задаче.
#    3. Провели исследовательский анализ данных, посмотрели распределение нового признака Увольнение, получили портрет уволившегося сотрудника - это недавно работающий не загруженный работой junior, которого не очень ценит руководитель, с низкой зарплатой.
#    4. Добавили новый входной признак (удовлетворенность работой) в тестовую и тренировочную выборки.
#    5. Провели подготовку данных (кодирование, масштабирование, обработка пропусков) с использованием пайплайна.
#    6. Целевой признак - Увольнение. Это задача бинарной классификации. Для бинарной классификации мы использовали модели логистической регрессии, метод опорных векторов, KNN и дерево решений (для всех использовали перебор разных гиперпараметров). Провели обучение моделей, выбрали лучшую на основе метрики ROC_AUC.
#    7. Лучше всего справилась модель SVC - метод опорных векторов. етрика ROC-AUC на тестовой выборке: 0.928. Больше всего на модель влияют следующие параметры: Стаж работы, уровень удовлетворённости и уровень занимаемой должности, а также зарплата
#
#    **Пожелания заказчику:**
#    Для того, чтобы сотрудники меньше увольнялись необходимо: следить за удовлетворенность работой, повышать уровень должности (быстрее переводить из Junior), и больше загружать работой и соответсвенно повышать уровень зарплаты.
